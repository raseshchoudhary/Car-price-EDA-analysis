# %% [markdown]
# # Assignment

# %%
import pandas as pd

# %%
df = pd.read_csv('carprice.csv')

# %%
df.head()
# Out:
#    symboling               CarName fueltype aspiration doornumber  \
# 0          2           audi 100 ls      gas        std       four
# 1          0           peugeot 504      gas        std       four
# 2          3  mitsubishi outlander      gas      turbo        two
# 3          1         toyota corona      gas        std        two
# 4          2       toyota cressida      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0        sedan        fwd          front       99.8      176.6  ...
# 1        wagon        rwd          front      114.2      198.9  ...
# 2    hatchback        fwd          front       95.9      173.2  ...
# 3    hatchback        fwd          front       95.7      158.7  ...
# 4  convertible        rwd          front       98.4      176.2  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         109        mpfi       3.19   3.40             10.0         102
# ...

# %% [markdown]
# # Question
# Give me some insights from this data. (Totally open ended, dazzle me with your brilliance ^_^ )
#
# Find me something meaningful that will help me as a business owner.
#
# ![](https://media.giphy.com/media/3oEjHAWsCGowjkc3Ha/giphy.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #                                                    # Start of the assignment

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Wheel base vs car length

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['wheelbase'],df['carlength'])
plt.xlabel('Wheel base')
plt.ylabel('Car length')
# Out:
# Text(0, 0.5, 'Car length')

# %% [markdown]
# # Interpretations:
# >There is a positive correlation berween wheelbase and carlength which means that cars with more length require a broader wheel base.
#
# >Thus if the aim is to make longer cars that the owner should keep in mind that the wheel base is also made broader and vice versa
#
# ![](https://media2.giphy.com/media/POImYt7LpFEHdBEoPV/giphy.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Which body type is most common?

# %%
df['carbody'].value_counts().plot(kind='bar')
plt.xlabel('Car Body Type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretations
# Majority of the customers tend to prefer sedan cars, where as convertibal cars are least prefered.
#
# ![](https://media.giphy.com/media/bhabX3oBFxPjO/giphy.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Which body type is the costliest?

# %%
df.groupby('carbody').mean()['price'].plot(kind='line',color=('red'))
plt.xlabel('Car Body Type')
plt.ylabel('Mean price')
# Out:
# Text(0, 0.5, 'Mean price')

# %% [markdown]
# # Interpretations
# As we saw in the above chart that sadan and hatchback carbody cars are more prefers, well the reason can be the price as we can see that these two car bodies are dead cheap. This indicates that the owner is dealing with price elastic customers.
#
#
# ![](https://www.bing.com/th/id/OGC.c77c77ed58d6456c855de7eb58e5994a?pid=1.7&rurl=https%3a%2f%2fmedia1.tenor.com%2fimages%2fc77c77ed58d6456c855de7eb58e5994a%2ftenor.gif%3fitemid%3d10734793&ehk=hHqfYtj1nUy7Vx0hI8PQU%2bRRL2rdUeCgSk%2bfYE6bLeg%3d)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Fuel type and frequency

# %%
df['fueltype'].value_counts().plot(kind='bar',color=('green','red'))
plt.xlabel('Fuel type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretations
# Most of the customers prefer gas cars instead of diesel ones. This could mean that we are dealing with low end customer who want budget cars and lot luxury ones.
# ![](https://www.bing.com/th/id/OGC.8b381ed9c51d957f8bfeb898497a45aa?pid=1.7&rurl=https%3a%2f%2fgiffiles.alphacoders.com%2f136%2f13690.gif&ehk=3DKyTKfE8SQXG2Guxjaz8Jaizey3Sqgo1YQO577kM80%3d)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %%
df['doornumber'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='doornumber'>

# %% [markdown]
# # Interpretations
# Since most customer prefer cars with 4 doors so tt can be deduced that most of them have a nuclear family with 4 members, although a good number of customer also prefer 2 door cars, who might be couples. In this case the owner might be dealing with the customers who are married and have children.
#
#
# ![](https://c.tenor.com/S_mVny2FO7gAAAAC/fam-family.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Distribution of car price (Histogram)

# %%
df['price'].hist(bins=20)
plt.xlabel('Car price')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretations:
# The above histogram is positively skewed.
# Majority of the cars that is owner is selling belongs to price range 15000 to 18000 because as mentioned that we are dealing with low end customers and very few are puchasing high end cars. This is just to give information to the owner about his target customers.
#
#
# ![](https://i.pinimg.com/originals/55/e6/c9/55e6c991789be3d300c1e403f7c0d725.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Car price vs horsepower

# %%
plt.scatter(df['price'],df['horsepower'],color=('green'))
plt.xlabel('Car Price')
plt.ylabel('Horsepower')
# Out:
# Text(0, 0.5, 'Horsepower')

# %% [markdown]
# # Interpretations
# There is a positive coorelation between price of the vehicle and its horsepower. Cars with higher horsepower means that they are comparatively stronger with the cars with weaker horsepower and since they are stronger, they need to be made with sturdier equiments that will eventuall cost more.
#
#
# ![](https://media.giphy.com/media/t7GFoK91krh284Ct8B/giphy.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Relation between engine size and car price

# %%
plt.scatter(df['price'],df['enginesize'],color=('red'))
plt.xlabel('Car price')
plt.ylabel('Engine size')
# Out:
# Text(0, 0.5, 'Engine size')

# %% [markdown]
# # Interpretation
# The more the engine size, the costlier the vehicle. If we combine the the above two graphs we can get to the conclusion that
# a large engine size leads to more horse power, in short engine size and horse power are also correlated. (Refer to the histogram below for more elaboration).
#
#
# ![](https://d2t1xqejof9utc.cloudfront.net/screenshots/pics/ab0ddd330576921650e6de0c63f6d7ba/medium.gif)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Distribution of engine size and horsepower

# %%
df['enginesize'].hist(bins=20)
df['horsepower'].hist(bins=20)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Interpretation
# As we can see that the histograms of both the engine size and horsepower are almost alike which indicates that one effects the other in a positive manner. This is to make the customer understand that if they wish to have a sturdy car with a high horse power that they need a car with a bigger engine which will eventually cost more. In other words engine size, horsepower and price of the car are mutually correlated with each other on a positive manner as indicated by the graphs above as well as by the histogram.
#
#
# ![](https://media1.tenor.com/images/31f6ce8a2381421d223140f3f70a3ce6/tenor.gif?itemid=5138628)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # The end
